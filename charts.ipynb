# %% [markdown]
# <a href="https://colab.research.google.com/github/mahakjain123456/basic_data_analysis_in_python/blob/main/charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('Energy_consumption.csv')
df.head()
df.describe()
# Out:
#        Temperature     Humidity  SquareFootage    Occupancy  RenewableEnergy  \
# count  1000.000000  1000.000000    1000.000000  1000.000000      1000.000000
# mean     24.982026    45.395412    1500.052488     4.581000        15.132813
# std       2.836850     8.518905     288.418873     2.865598         8.745917
# min      20.007565    30.015975    1000.512661     0.000000         0.006642
# 25%      22.645070    38.297722    1247.108548     2.000000         7.628385
# 50%      24.751637    45.972116    1507.967426     5.000000        15.072296
# 75%      27.418174    52.420066    1740.340165     7.000000        22.884064
# max      29.998671    59.969085    1999.982252     9.000000        29.965327
#
#        EnergyConsumption
# count        1000.000000
# mean           77.055873
# std             8.144112
# min            53.263278
# 25%            71.544690
# 50%            76.943696
# 75%            82.921742
# max            99.201120
# ...

# %%
df['Temperature'].head()
# Out:
# 0    25.139433
# 1    27.731651
# 2    28.704277
# 3    20.080469
# 4    23.097359
# Name: Temperature, dtype: float64

# %%
df.loc[3]
# Out:
# Timestamp            2022-01-01 03:00:00
# Temperature                    20.080469
# Humidity                       50.371637
# SquareFootage                1452.316318
# Occupancy                              1
# HVACUsage                            Off
# LightingUsage                         On
# RenewableEnergy                 8.623447
# DayOfWeek                      Wednesday
# Holiday                               No
# EnergyConsumption               56.51985
# Name: 3, dtype: object

# %%
filter_df=df[df['Temperature']>29.90]
filter_df
# Out:
#                Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 37   2022-01-02 13:00:00    29.913830  53.340753    1924.186121          0
# 45   2022-01-02 21:00:00    29.988046  51.196630    1516.752703          2
# 54   2022-01-03 06:00:00    29.956879  56.788806    1864.732366          8
# 91   2022-01-04 19:00:00    29.950503  42.425258    1679.773172          4
# 185  2022-01-08 17:00:00    29.954995  55.096539    1107.202980          5
# 292  2022-01-13 04:00:00    29.927676  54.179141    1182.709460          1
# 320  2022-01-14 08:00:00    29.971165  30.521684    1868.887373          5
# 334  2022-01-14 22:00:00    29.940554  51.648907    1581.513932          8
# 355  2022-01-15 19:00:00    29.934092  51.026985    1008.280994          2
# 379  2022-01-16 19:00:00    29.989584  48.613264    1933.022912          4
# 408  2022-01-18 00:00:00    29.963233  52.727922    1419.504118          5
# ...

# %%
df['newOccupancy']=df['Occupancy']+2
df.head()
# Out:
#              Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0  2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1  2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2  2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3  2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4  2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
#
#   HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# 0        On           Off         2.774699     Monday      No
# 1        On            On        21.831384   Saturday      No
# 2       Off           Off         6.764672     Sunday      No
# 3       Off            On         8.623447  Wednesday      No
# 4        On           Off         3.071969     Friday      No
#
#    EnergyConsumption  newOccupancy
# 0          75.364373             7
# 1          83.401855             3
# 2          78.270888             4
# ...

# %%
grouped_df=df.groupby('DayOfWeek').count()
grouped_df.head()
# Out:
#            Timestamp  Temperature  Humidity  SquareFootage  Occupancy  \
# DayOfWeek
# Friday           164          164       164            164        164
# Monday           123          123       123            123        123
# Saturday         143          143       143            143        143
# Sunday           154          154       154            154        154
# Thursday         146          146       146            146        146
#
#            HVACUsage  LightingUsage  RenewableEnergy  Holiday  \
# DayOfWeek
# Friday           164            164              164      164
# Monday           123            123              123      123
# Saturday         143            143              143      143
# Sunday           154            154              154      154
# Thursday         146            146              146      146
#
#            EnergyConsumption  newOccupancy
# DayOfWeek
# Friday                   164           164
# Monday                   123           123
# ...

# %%
import numpy as np
a=np.array([0,1,2,3,4])
print(a)
print(type(a))
print(a.ndim)
print(a.shape)
print(len(a))
print(a.dtype)
# Out:
# [0 1 2 3 4]
# <class 'numpy.ndarray'>
# 1
# (5,)
# 5
# int64

# %%
my_list=[[1,2,3],[4,5,6],[7,8,9]]
np.array(my_list)
# Out:
# array([0.513866  , 0.87546165, 0.09092286, 0.54767951, 0.94053383])

# %%
np.random.rand(5)
# Out:
# array([0.77575891, 0.32167916, 0.89210667, 0.71162842, 0.81621825])

# %%
np.random.rand(5,5)
# Out:
# array([[0.72945603, 0.16671858, 0.94503862, 0.08658977, 0.45807418],
#        [0.10447231, 0.34927907, 0.126983  , 0.09377565, 0.36114017],
#        [0.59695808, 0.09067986, 0.33632319, 0.62476962, 0.57618541],
#        [0.82588621, 0.44973246, 0.79826279, 0.77743681, 0.02165431],
#        [0.89926095, 0.6948544 , 0.67992271, 0.41117736, 0.06591001]])

# %%
np.random.randn(5)
# Out:
# array([-2.59406303, -1.88294525,  0.06033235, -0.9532059 , -0.0137885 ])

# %%
np.random.randint(0,10,5)
# Out:
# array([3, 8, 1, 7, 0])

# %%
from matplotlib import pyplot as plt
x=[5,2,7]
y=[2,16,4]
plt.bar(x,y)
plt.title('info')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
sns.barplot(x="day", y="total_bill", data=tips);

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
numeric_data = tips.select_dtypes(include=['number'])
sns.violinplot(numeric_data.corr(),cmap="coolwarm");
